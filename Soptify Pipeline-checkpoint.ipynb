# %%
pip install spotipy
# Out:
# ...
#                                               0.0/250.3 kB ? eta -:--:--
#      --------------                          92.2/250.3 kB 2.6 MB/s eta 0:00:01
#      -------------------------------        204.8/250.3 kB 2.5 MB/s eta 0:00:01
#      -------------------------------------- 250.3/250.3 kB 2.6 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
client_cred_manager=SpotifyClientCredentials(client_id="3f2ab1f1df174aa884148c9c6639403a",client_secret="fcf1c4f6b81b4a9b95770288c9819f84")

# %%
spotify = spotipy.Spotify(client_credentials_manager=client_cred_manager)

# %%
playlist_link="https://open.spotify.com/playlist/37i9dQZF1DX5cZuAHLNjGz"

# %%
playlist_uri=playlist_link.split("/")[4]

# %%
playlist_uri
# Out:
# '37i9dQZF1DX5cZuAHLNjGz'

# %%
song_data=spotify.playlist_tracks(playlist_uri)

# %%
song_data
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX5cZuAHLNjGz/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2023-10-03T07:31:43Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5r3wPya2PpeTTsXsGhQU8O'},
#        'href': 'https://api.spotify.com/v1/artists/5r3wPya2PpeTTsXsGhQU8O',
#        'id': '5r3wPya2PpeTTsXsGhQU8O',
#        'name': 'Shubh',
#        'type': 'artist',
#        'uri': 'spotify:artist:5r3wPya2PpeTTsXsGhQU8O'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
# ...

# %%
total_track=len(song_data['items'])

# %%
song_data['items'][0]['track']['album']
# Out:
# {'album_type': 'album',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5r3wPya2PpeTTsXsGhQU8O'},
#    'href': 'https://api.spotify.com/v1/artists/5r3wPya2PpeTTsXsGhQU8O',
#    'id': '5r3wPya2PpeTTsXsGhQU8O',
#    'name': 'Shubh',
#    'type': 'artist',
#    'uri': 'spotify:artist:5r3wPya2PpeTTsXsGhQU8O'}],
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
# ...

# %%
album_list=[]
for i in range(total_track):
    album_id=song_data['items'][i]['track']['album']['id']
    album_name=song_data['items'][i]['track']['album']['name']
    album_release_date=song_data['items'][i]['track']['album']['release_date']
    album_total_tracks=song_data['items'][i]['track']['album']['total_tracks']
    album_URL=song_data['items'][i]['track']['album']['external_urls']['spotify']
    album_elements={'album_id':album_id,'album_name':album_name,'album_release_date':album_release_date,'album_total_tracks':album_total_tracks,'album_url':album_URL}
#     print(album_elements)
    album_list.append(album_elements)
# Out:
# {'album_id': '5AivaZj0CiQJoDWqVH2pbh', 'album_name': 'Still Rollin', 'album_release_date': '2023-05-19', 'album_total_tracks': 7, 'album_url': 'https://open.spotify.com/album/5AivaZj0CiQJoDWqVH2pbh'}
# {'album_id': '1d1FYLFpu2NITI6ilVaHDd', 'album_name': 'Ghost', 'album_release_date': '2023-09-29', 'album_total_tracks': 22, 'album_url': 'https://open.spotify.com/album/1d1FYLFpu2NITI6ilVaHDd'}
# {'album_id': '0azGrKHPYvl2MEKwQFfbV2', 'album_name': 'Mi Amor', 'album_release_date': '2022-09-30', 'album_total_tracks': 1, 'album_url': 'https://open.spotify.com/album/0azGrKHPYvl2MEKwQFfbV2'}
# {'album_id': '30eM1PJ8qLZJeEykhcje0j', 'album_name': 'With You', 'album_release_date': '2023-08-11', 'album_total_tracks': 1, 'album_url': 'https://open.spotify.com/album/30eM1PJ8qLZJeEykhcje0j'}
# {'album_id': '3BGU0BqGwBkYDHpfCWFm7I', 'album_name': 'Making Memories', 'album_release_date': '2023-08-18', 'album_total_tracks': 9, 'album_url': 'https://open.spotify.com/album/3BGU0BqGwBkYDHpfCWFm7I'}
# ...

# %%
song_data['items'][0]['track']['name']
# Out:
# 'Cheques'

# %%
# Out:
# ['Still Rollin',
#  'Ghost',
#  'Mi Amor',
#  'With You',
#  'Making Memories',
#  'ANYWAY',
#  'Daku',
#  'Ghost',
#  'Making Memories',
#  '1996',
#  'Palpita',
#  'Ayee',
#  'Jordan Sandhu Hits',
#  'Custom Plates',
#  'Check It Out',
#  'Still Rollin',
#  'White Brown Black',
#  '9:45',
#  'Naveezy',
#  'Rubicon',
#  'Tareefan',
#  'One Love',
#  'Obsessed',
#  'Street Knowledge',
#  'Mexico',
#  'Takeover',
#  'Aam Jahe Munde',
#  'Showstopper',
#  "Admirin' You (feat. Preston Pablo)",
#  'Udh Di Phiran',
#  'Forever',
#  'Baller',
#  'Players',
#  'Chorni',
#  'True Stories',
#  'Attraction',
#  'Silicone',
#  'Nimm Thalle',
#  'Drive Thru',
#  'Echoes of Emotions',
#  'Still Rollin',
#  'GLOBAL WARNING',
#  'Thaa',
#  'Saroor',
#  'Sleepless',
#  'No Love',
#  "SWITCHIN' LANES",
#  'P.O.V (Point of View)',
#  'Do You Know',
#  'Still Rollin',
#  'Four You',
#  'Pagol',
#  'Todh',
#  'VIBIN',
#  'Man Of The Moon',
#  'Mera Na',
#  'Back To Skool',
#  'Saroor',
#  'Afterhours',
# ...
